# %% [markdown]
# # Регрессия дерева решений

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("data/after_3s.csv")
df.drop(columns =['Unnamed: 0'], axis = 1, inplace = True)
df.head()
df_new = df
df
# Out:
#      Соотношение матрица-наполнитель  Плотность, кг/м3  модуль упругости, ГПа  \
# 0                           1.857143       2030.000000              -0.003593
# 1                           1.857143       2030.000000              -0.003593
# 2                           2.771331       2030.000000               0.039599
# 3                           2.767918       2000.000000               0.024458
# 4                           2.569620       1910.000000               0.203120
# ..                               ...               ...                    ...
# 994                         2.271346       1952.087902               0.523670
# 995                         3.444022       2050.089171              -0.893890
# 996                         3.280604       1972.372865              -0.978364
# 997                         3.705351       2066.799773               0.004701
# 998                         3.808020       1890.413468              -0.976911
#
# ...

# %%
df_sortir = df_new.sort_values('Плотность, кг/м3')
df_sortir = df_sortir.reset_index()
a = df_sortir['Плотность, кг/м3']
a1 = a.iloc[200:800]
plt.plot(a1)
df_sortir1.to_csv('data/df_sortir.csv')
df_sortir1.to_excel('data/df_sortir.xlsx')

# %%
df_new = pd.read_excel("data/df_sortir.xlsx")
df_new.drop(columns =['Unnamed: 0'], axis = 1, inplace = True)
df_new.head()
# Out:
#    index  Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 0    316                         2.995125               NaN
# 1    198                         2.929276               NaN
# 2    575                         3.307697               NaN
# 3    540                         4.018220               NaN
# 4    974                         4.338272               NaN
#
#    модуль упругости, ГПа  Количество отвердителя, м.%  \
# 0               0.714419                    81.441620
# 1               0.582084                   103.351907
# 2               0.203315                   120.065258
# 3              -0.033181                   133.637841
# 4              -0.155336                   100.676847
#
#    Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 0                        19.709615                317.816859
# 1                        25.282319                274.485907
# 2                        23.882251                305.439343
# ...

# %%
df_sortir = df_new.sort_values('Соотношение матрица-наполнитель')
df_sortir = df_sortir.reset_index()
b = df_sortir['Соотношение матрица-наполнитель']
b1 = b.iloc[200:800]

plt.plot(b1)

# %%
df_sortir
# Out:
#      level_0  index  Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 0        222    655                         0.389403       1917.699889
# 1        287    764                         0.547391       1931.739832
# 2        296    390                         0.551508       1934.555670
# 3        278    798                         0.596783       1930.389172
# 4        387    909                         0.749223       1957.475842
# ..       ...    ...                              ...               ...
# 994      579    872                         5.314144       1989.694082
# 995      647    275                         5.425139       2003.272119
# 996      229    488                         5.452959       1918.688919
# 997      950    854                         5.455566               NaN
# 998      969    230                         5.591742               NaN
#
#      модуль упругости, ГПа  Количество отвердителя, м.%  \
# 0                -0.417374                    93.346585
# ...

# %%
df_sortir.to_csv('data/df_sortir1.csv')
df_sortir.to_excel('data/df_sortir1.xlsx')

# %%
df_sortir = df_new.sort_values('модуль упругости, ГПа')
df_sortir = df_sortir.reset_index()
plt.plot(df_sortir['модуль упругости, ГПа'])

# %%
df_sortir = df_new.sort_values('Количество отвердителя, м.%')
df_sortir = df_sortir.reset_index()
plt.plot(df_sortir['Количество отвердителя, м.%'])

# %%
df_sortir = df_new.sort_values('Содержание эпоксидных групп,%_2')
df_sortir = df_sortir.reset_index()
plt.plot(df_sortir['Содержание эпоксидных групп,%_2'])

# %%
df_sortir = df_new.sort_values('Поверхностная плотность, г/м2')
df_sortir = df_sortir.reset_index()
plt.plot(df_sortir['Поверхностная плотность, г/м2'])

# %%
plt.plot(a.iloc[200:800])
plt.plot(b.iloc[200:800])

# %%
df1 = pd.read_excel("data/df_sortir1.xlsx")
df1.drop(columns =['Unnamed: 0'], axis = 1, inplace = True)
df1.head(10)
# Out:
#    level_0  index  Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 0      222    655                              NaN       1917.699889
# 1      287    764                              NaN       1931.739832
# 2      296    390                              NaN       1934.555670
# 3      278    798                              NaN       1930.389172
# 4      387    909                              NaN       1957.475842
# 5      235    901                              NaN       1920.051313
# 6      816    521                              NaN               NaN
# 7      750    839                              NaN       2021.354918
# 8      370    867                              NaN       1952.857390
# 9      189    914                              NaN               NaN
#
#    модуль упругости, ГПа  Количество отвердителя, м.%  \
# 0              -0.417374                    93.346585
# 1              -1.863588                   121.151346
# ...

# %%
df1.dropna()
# Out:
#      level_0  index  Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 199      709    758                         2.159406       2014.646229
# 201      696    955                         2.162067       2012.590171
# 202      767    673                         2.163429       2025.648229
# 203      204    567                         2.163567       1913.021899
# 205      756    118                         2.167217       2021.810983
# ..       ...    ...                              ...               ...
# 791      722    616                         3.675442       2016.367415
# 792      763    707                         3.676137       2025.275103
# 793      656    271                         3.678477       2005.412966
# 794      376    985                         3.679310       1953.873794
# 797      285    803                         3.688037       1931.378176
#
#      модуль упругости, ГПа  Количество отвердителя, м.%  \
# 199               0.709399                   104.042877
# ...

# %%
df = df1.dropna()

# %%
X = df['Соотношение матрица-наполнитель'].values.reshape(-1,1)
y = df['Плотность, кг/м3'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
#compare actual output values with predicted values
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df.head()
# Out:
#         Actual    Predicted
# 0  1961.550076  1974.669474
# 1  1949.183593  1978.413879
# 2  1968.953083  1973.039429
# 3  1958.143379  1972.393464
# 4  1965.752439  1973.956675

# %%
plt.scatter(X_test, y_test,  color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()
