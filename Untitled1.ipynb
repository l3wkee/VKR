# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("data/after_inner.csv")
df.drop(columns =['Unnamed: 0'], axis = 1, inplace = True)
df.head()
# Out:
#    Соотношение матрица-наполнитель  Плотность, кг/м3  модуль упругости, ГПа  \
# 0                         1.857143            2030.0             738.736842
# 1                         1.857143            2030.0             738.736842
# 2                         1.857143            2030.0             738.736842
# 3                         1.857143            2030.0             738.736842
# 4                         2.771331            2030.0             753.000000
#
#    Количество отвердителя, м.%  Содержание эпоксидных групп,%_2  \
# 0                        30.00                        22.267857
# 1                        50.00                        23.750000
# 2                        49.90                        33.000000
# 3                       129.00                        21.250000
# 4                       111.86                        22.267857
#
#    Температура вспышки, С_2  Поверхностная плотность, г/м2  \
# 0                100.000000                          210.0
# 1                284.615385                          210.0
# 2                284.615385                          210.0
# 3                300.000000                          210.0
# 4                284.615385                          210.0
#
#    Модуль упругости при растяжении, ГПа  Прочность при растяжении, МПа  \
# 0                                  70.0                         3000.0
# 1                                  70.0                         3000.0
# 2                                  70.0                         3000.0
# 3                                  70.0                         3000.0
# 4                                  70.0                         3000.0
#
#    Потребление смолы, г/м2  Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 0                    220.0                 0.0          4.0               57.0
# 1                    220.0                 0.0          4.0               60.0
# 2                    220.0                 0.0          4.0               70.0
# 3                    220.0                 0.0          5.0               47.0
# 4                    220.0                 0.0          5.0               57.0

# %%
df.astype('float32')
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 0                            1.857143       2030.000000
# 1                            1.857143       2030.000000
# 2                            1.857143       2030.000000
# 3                            1.857143       2030.000000
# 4                            2.771331       2030.000000
# ...                               ...               ...
# 1018                         2.271346       1952.087891
# 1019                         3.444022       2050.089111
# 1020                         3.280604       1972.372925
# 1021                         3.705351       2066.799805
# 1022                         3.808020       1890.413452
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# 0                738.736816                    30.000000
# 1                738.736816                    50.000000
# 2                738.736816                    49.900002
# 3                738.736816                   129.000000
# 4                753.000000                   111.860001
# ...                     ...                          ...
# 1018             912.855530                    86.992180
# 1019             444.732635                   145.981979
# 1020             416.836517                   110.533478
# 1021             741.475525                   141.397964
# 1022             417.316223                   129.183411
#
#       Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 0                           22.267857                100.000000
# 1                           23.750000                284.615387
# 2                           33.000000                284.615387
# 3                           21.250000                300.000000
# 4                           22.267857                284.615387
# ...                               ...                       ...
# 1018                        20.123249                324.774567
# 1019                        19.599770                254.215408
# 1020                        23.957502                248.423050
# 1021                        19.246944                275.779846
# 1022                        27.474764                300.952698
#
#       Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 0                        210.000000                             70.000000
# 1                        210.000000                             70.000000
# 2                        210.000000                             70.000000
# 3                        210.000000                             70.000000
# 4                        210.000000                             70.000000
# ...                             ...                                   ...
# 1018                     209.198700                             73.090958
# 1019                     350.660828                             72.920830
# 1020                     740.142761                             74.734344
# 1021                     641.468140                             74.042709
# 1022                     758.747864                             74.309708
#
#       Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 0                       3000.000000               220.000000
# 1                       3000.000000               220.000000
# 2                       3000.000000               220.000000
# 3                       3000.000000               220.000000
# 4                       3000.000000               220.000000
# ...                             ...                      ...
# 1018                    2387.292480               125.007668
# 1019                    2360.392822               117.730095
# 1020                    2662.906006               236.606766
# 1021                    2071.715820               197.126068
# 1022                    2856.328857               194.754349
#
#       Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 0                    0.0     4.000000          57.000000
# 1                    0.0     4.000000          60.000000
# 2                    0.0     4.000000          70.000000
# 3                    0.0     5.000000          47.000000
# 4                    0.0     5.000000          57.000000
# ...                  ...          ...                ...
# 1018                90.0     9.076381          47.019772
# 1019                90.0    10.565614          53.750790
# 1020                90.0     4.161154          67.629684
# 1021                90.0     6.313201          58.261074
# 1022                90.0     6.078902          77.434471
#
# [1023 rows x 13 columns]

# %%
df = df#.iloc[:23]
df
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 0                            1.857143       2030.000000
# 1                            1.857143       2030.000000
# 2                            1.857143       2030.000000
# 3                            1.857143       2030.000000
# 4                            2.771331       2030.000000
# ...                               ...               ...
# 1018                         2.271346       1952.087902
# 1019                         3.444022       2050.089171
# 1020                         3.280604       1972.372865
# 1021                         3.705351       2066.799773
# 1022                         3.808020       1890.413468
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# 0                738.736842                    30.000000
# 1                738.736842                    50.000000
# 2                738.736842                    49.900000
# 3                738.736842                   129.000000
# 4                753.000000                   111.860000
# ...                     ...                          ...
# 1018             912.855545                    86.992183
# 1019             444.732634                   145.981978
# 1020             416.836524                   110.533477
# 1021             741.475517                   141.397963
# 1022             417.316232                   129.183416
#
#       Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 0                           22.267857                100.000000
# 1                           23.750000                284.615385
# 2                           33.000000                284.615385
# 3                           21.250000                300.000000
# 4                           22.267857                284.615385
# ...                               ...                       ...
# 1018                        20.123249                324.774576
# 1019                        19.599769                254.215401
# 1020                        23.957502                248.423047
# 1021                        19.246945                275.779840
# 1022                        27.474763                300.952708
#
#       Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 0                        210.000000                             70.000000
# 1                        210.000000                             70.000000
# 2                        210.000000                             70.000000
# 3                        210.000000                             70.000000
# 4                        210.000000                             70.000000
# ...                             ...                                   ...
# 1018                     209.198700                             73.090961
# 1019                     350.660830                             72.920827
# 1020                     740.142791                             74.734344
# 1021                     641.468152                             74.042708
# 1022                     758.747882                             74.309704
#
#       Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 0                       3000.000000               220.000000
# 1                       3000.000000               220.000000
# 2                       3000.000000               220.000000
# 3                       3000.000000               220.000000
# 4                       3000.000000               220.000000
# ...                             ...                      ...
# 1018                    2387.292495               125.007669
# 1019                    2360.392784               117.730099
# 1020                    2662.906040               236.606764
# 1021                    2071.715856               197.126067
# 1022                    2856.328932               194.754342
#
#       Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 0                    0.0     4.000000          57.000000
# 1                    0.0     4.000000          60.000000
# 2                    0.0     4.000000          70.000000
# 3                    0.0     5.000000          47.000000
# 4                    0.0     5.000000          57.000000
# ...                  ...          ...                ...
# 1018                90.0     9.076380          47.019770
# 1019                90.0    10.565614          53.750790
# 1020                90.0     4.161154          67.629684
# 1021                90.0     6.313201          58.261074
# 1022                90.0     6.078902          77.434468
#
# [1023 rows x 13 columns]

# %%
df1 = df.drop_duplicates(subset=['Соотношение матрица-наполнитель'], keep='last')

# %%
df1
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 3                            1.857143       2030.000000
# 4                            2.771331       2030.000000
# 5                            2.767918       2000.000000
# 6                            2.569620       1910.000000
# 7                            2.561475       1900.000000
# ...                               ...               ...
# 1018                         2.271346       1952.087902
# 1019                         3.444022       2050.089171
# 1020                         3.280604       1972.372865
# 1021                         3.705351       2066.799773
# 1022                         3.808020       1890.413468
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# 3                738.736842                   129.000000
# 4                753.000000                   111.860000
# 5                748.000000                   111.860000
# 6                807.000000                   111.860000
# 7                535.000000                   111.860000
# ...                     ...                          ...
# 1018             912.855545                    86.992183
# 1019             444.732634                   145.981978
# 1020             416.836524                   110.533477
# 1021             741.475517                   141.397963
# 1022             417.316232                   129.183416
#
#       Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 3                           21.250000                300.000000
# 4                           22.267857                284.615385
# 5                           22.267857                284.615385
# 6                           22.267857                284.615385
# 7                           22.267857                284.615385
# ...                               ...                       ...
# 1018                        20.123249                324.774576
# 1019                        19.599769                254.215401
# 1020                        23.957502                248.423047
# 1021                        19.246945                275.779840
# 1022                        27.474763                300.952708
#
#       Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 3                        210.000000                             70.000000
# 4                        210.000000                             70.000000
# 5                        210.000000                             70.000000
# 6                        210.000000                             70.000000
# 7                        380.000000                             75.000000
# ...                             ...                                   ...
# 1018                     209.198700                             73.090961
# 1019                     350.660830                             72.920827
# 1020                     740.142791                             74.734344
# 1021                     641.468152                             74.042708
# 1022                     758.747882                             74.309704
#
#       Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 3                       3000.000000               220.000000
# 4                       3000.000000               220.000000
# 5                       3000.000000               220.000000
# 6                       3000.000000               220.000000
# 7                       1800.000000               120.000000
# ...                             ...                      ...
# 1018                    2387.292495               125.007669
# 1019                    2360.392784               117.730099
# 1020                    2662.906040               236.606764
# 1021                    2071.715856               197.126067
# 1022                    2856.328932               194.754342
#
#       Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 3                    0.0     5.000000          47.000000
# 4                    0.0     5.000000          57.000000
# 5                    0.0     5.000000          60.000000
# 6                    0.0     5.000000          70.000000
# 7                    0.0     7.000000          47.000000
# ...                  ...          ...                ...
# 1018                90.0     9.076380          47.019770
# 1019                90.0    10.565614          53.750790
# 1020                90.0     4.161154          67.629684
# 1021                90.0     6.313201          58.261074
# 1022                90.0     6.078902          77.434468
#
# [1014 rows x 13 columns]

# %%
df2 = df1.drop_duplicates(subset=['Плотность, кг/м3'], keep='last')

# %%
df2
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 6                            2.569620       1910.000000
# 7                            2.561475       1900.000000
# 15                           2.934783       2030.000000
# 17                           4.193548       1950.000000
# 18                           4.897959       1890.000000
# ...                               ...               ...
# 1018                         2.271346       1952.087902
# 1019                         3.444022       2050.089171
# 1020                         3.280604       1972.372865
# 1021                         3.705351       2066.799773
# 1022                         3.808020       1890.413468
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# 6                807.000000                   111.860000
# 7                535.000000                   111.860000
# 15               302.000000                   129.000000
# 17               506.000000                   129.000000
# 18               540.000000                   129.000000
# ...                     ...                          ...
# 1018             912.855545                    86.992183
# 1019             444.732634                   145.981978
# 1020             416.836524                   110.533477
# 1021             741.475517                   141.397963
# 1022             417.316232                   129.183416
#
#       Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 6                           22.267857                284.615385
# 7                           22.267857                284.615385
# 15                          21.250000                300.000000
# 17                          21.250000                300.000000
# 18                          21.250000                300.000000
# ...                               ...                       ...
# 1018                        20.123249                324.774576
# 1019                        19.599769                254.215401
# 1020                        23.957502                248.423047
# 1021                        19.246945                275.779840
# 1022                        27.474763                300.952708
#
#       Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 6                        210.000000                             70.000000
# 7                        380.000000                             75.000000
# 15                       210.000000                             70.000000
# 17                       380.000000                             75.000000
# 18                       380.000000                             75.000000
# ...                             ...                                   ...
# 1018                     209.198700                             73.090961
# 1019                     350.660830                             72.920827
# 1020                     740.142791                             74.734344
# 1021                     641.468152                             74.042708
# 1022                     758.747882                             74.309704
#
#       Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 6                       3000.000000               220.000000
# 7                       1800.000000               120.000000
# 15                      3000.000000               220.000000
# 17                      1800.000000               120.000000
# 18                      1800.000000               120.000000
# ...                             ...                      ...
# 1018                    2387.292495               125.007669
# 1019                    2360.392784               117.730099
# 1020                    2662.906040               236.606764
# 1021                    2071.715856               197.126067
# 1022                    2856.328932               194.754342
#
#       Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 6                    0.0     5.000000          70.000000
# 7                    0.0     7.000000          47.000000
# 15                   0.0    10.000000          47.000000
# 17                   0.0    10.000000          60.000000
# 18                   0.0    10.000000          70.000000
# ...                  ...          ...                ...
# 1018                90.0     9.076380          47.019770
# 1019                90.0    10.565614          53.750790
# 1020                90.0     4.161154          67.629684
# 1021                90.0     6.313201          58.261074
# 1022                90.0     6.078902          77.434468
#
# [1009 rows x 13 columns]

# %%
df3 = df2.drop_duplicates(subset=['модуль упругости, ГПа'], keep='last')

# %%
df3
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 6                            2.569620       1910.000000
# 7                            2.561475       1900.000000
# 15                           2.934783       2030.000000
# 17                           4.193548       1950.000000
# 18                           4.897959       1890.000000
# ...                               ...               ...
# 1018                         2.271346       1952.087902
# 1019                         3.444022       2050.089171
# 1020                         3.280604       1972.372865
# 1021                         3.705351       2066.799773
# 1022                         3.808020       1890.413468
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# 6                807.000000                   111.860000
# 7                535.000000                   111.860000
# 15               302.000000                   129.000000
# 17               506.000000                   129.000000
# 18               540.000000                   129.000000
# ...                     ...                          ...
# 1018             912.855545                    86.992183
# 1019             444.732634                   145.981978
# 1020             416.836524                   110.533477
# 1021             741.475517                   141.397963
# 1022             417.316232                   129.183416
#
#       Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 6                           22.267857                284.615385
# 7                           22.267857                284.615385
# 15                          21.250000                300.000000
# 17                          21.250000                300.000000
# 18                          21.250000                300.000000
# ...                               ...                       ...
# 1018                        20.123249                324.774576
# 1019                        19.599769                254.215401
# 1020                        23.957502                248.423047
# 1021                        19.246945                275.779840
# 1022                        27.474763                300.952708
#
#       Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 6                        210.000000                             70.000000
# 7                        380.000000                             75.000000
# 15                       210.000000                             70.000000
# 17                       380.000000                             75.000000
# 18                       380.000000                             75.000000
# ...                             ...                                   ...
# 1018                     209.198700                             73.090961
# 1019                     350.660830                             72.920827
# 1020                     740.142791                             74.734344
# 1021                     641.468152                             74.042708
# 1022                     758.747882                             74.309704
#
#       Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 6                       3000.000000               220.000000
# 7                       1800.000000               120.000000
# 15                      3000.000000               220.000000
# 17                      1800.000000               120.000000
# 18                      1800.000000               120.000000
# ...                             ...                      ...
# 1018                    2387.292495               125.007669
# 1019                    2360.392784               117.730099
# 1020                    2662.906040               236.606764
# 1021                    2071.715856               197.126067
# 1022                    2856.328932               194.754342
#
#       Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 6                    0.0     5.000000          70.000000
# 7                    0.0     7.000000          47.000000
# 15                   0.0    10.000000          47.000000
# 17                   0.0    10.000000          60.000000
# 18                   0.0    10.000000          70.000000
# ...                  ...          ...                ...
# 1018                90.0     9.076380          47.019770
# 1019                90.0    10.565614          53.750790
# 1020                90.0     4.161154          67.629684
# 1021                90.0     6.313201          58.261074
# 1022                90.0     6.078902          77.434468
#
# [1009 rows x 13 columns]

# %%
df4 = df3.drop_duplicates(subset=['Количество отвердителя, м.%'], keep='last')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1002 entries, 18 to 1022
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Соотношение матрица-наполнитель       1002 non-null   float64
#  1   Плотность, кг/м3                      1002 non-null   float64
#  2   модуль упругости, ГПа                 1002 non-null   float64
#  3   Количество отвердителя, м.%           1002 non-null   float64
#  4   Содержание эпоксидных групп,%_2       1002 non-null   float64
#  5   Температура вспышки, С_2              1002 non-null   float64
#  6   Поверхностная плотность, г/м2         1002 non-null   float64
#  7   Модуль упругости при растяжении, ГПа  1002 non-null   float64
#  8   Прочность при растяжении, МПа         1002 non-null   float64
#  9   Потребление смолы, г/м2               1002 non-null   float64
#  10  Угол нашивки, град                    1002 non-null   float64
#  11  Шаг нашивки                           1002 non-null   float64
#  12  Плотность нашивки                     1002 non-null   float64
# dtypes: float64(13)
# memory usage: 109.6 KB

# %%
df5 = df4.drop_duplicates(subset=['Содержание эпоксидных групп,%_2'], keep='last')

# %%
df5
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 18                           4.897959       1890.000000
# 22                           4.029126       1880.000000
# 23                           2.587348       1953.274926
# 24                           2.499918       1942.595777
# 25                           2.046471       2037.631811
# ...                               ...               ...
# 1018                         2.271346       1952.087902
# 1019                         3.444022       2050.089171
# 1020                         3.280604       1972.372865
# 1021                         3.705351       2066.799773
# 1022                         3.808020       1890.413468
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# 18               540.000000                   129.000000
# 22               622.000000                   111.860000
# 23              1136.596135                   137.627420
# 24               901.519947                   146.252208
# 25               707.570887                   101.617251
# ...                     ...                          ...
# 1018             912.855545                    86.992183
# 1019             444.732634                   145.981978
# 1020             416.836524                   110.533477
# 1021             741.475517                   141.397963
# 1022             417.316232                   129.183416
#
#       Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 18                          21.250000                300.000000
# 22                          22.267857                284.615385
# 23                          22.344534                234.716883
# 24                          23.081757                351.231874
# 25                          23.146393                312.307205
# ...                               ...                       ...
# 1018                        20.123249                324.774576
# 1019                        19.599769                254.215401
# 1020                        23.957502                248.423047
# 1021                        19.246945                275.779840
# 1022                        27.474763                300.952708
#
#       Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 18                       380.000000                             75.000000
# 22                       470.000000                             73.333333
# 23                       555.893453                             80.803222
# 24                       864.725484                             76.178075
# 25                       547.601219                             73.817067
# ...                             ...                                   ...
# 1018                     209.198700                             73.090961
# 1019                     350.660830                             72.920827
# 1020                     740.142791                             74.734344
# 1021                     641.468152                             74.042708
# 1022                     758.747882                             74.309704
#
#       Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 18                      1800.000000               120.000000
# 22                      2455.555556               220.000000
# 23                      2587.342983               246.613117
# 24                      3705.672523               226.222760
# 25                      2624.026407               178.198556
# ...                             ...                      ...
# 1018                    2387.292495               125.007669
# 1019                    2360.392784               117.730099
# 1020                    2662.906040               236.606764
# 1021                    2071.715856               197.126067
# 1022                    2856.328932               194.754342
#
#       Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 18                   0.0    10.000000          70.000000
# 22                  90.0     4.000000          60.000000
# 23                  90.0     4.000000          70.000000
# 24                  90.0     5.000000          47.000000
# 25                  90.0     5.000000          57.000000
# ...                  ...          ...                ...
# 1018                90.0     9.076380          47.019770
# 1019                90.0    10.565614          53.750790
# 1020                90.0     4.161154          67.629684
# 1021                90.0     6.313201          58.261074
# 1022                90.0     6.078902          77.434468
#
# [1002 rows x 13 columns]

# %%
df6 = df5.drop_duplicates(subset=['Температура вспышки, С_2'], keep='last')

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1002 entries, 18 to 1022
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Соотношение матрица-наполнитель       1002 non-null   float64
#  1   Плотность, кг/м3                      1002 non-null   float64
#  2   модуль упругости, ГПа                 1002 non-null   float64
#  3   Количество отвердителя, м.%           1002 non-null   float64
#  4   Содержание эпоксидных групп,%_2       1002 non-null   float64
#  5   Температура вспышки, С_2              1002 non-null   float64
#  6   Поверхностная плотность, г/м2         1002 non-null   float64
#  7   Модуль упругости при растяжении, ГПа  1002 non-null   float64
#  8   Прочность при растяжении, МПа         1002 non-null   float64
#  9   Потребление смолы, г/м2               1002 non-null   float64
#  10  Угол нашивки, град                    1002 non-null   float64
#  11  Шаг нашивки                           1002 non-null   float64
#  12  Плотность нашивки                     1002 non-null   float64
# dtypes: float64(13)
# memory usage: 109.6 KB

# %%
df7 = df6.drop_duplicates(subset=['Поверхностная плотность, г/м2'], keep='last')

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1002 entries, 18 to 1022
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Соотношение матрица-наполнитель       1002 non-null   float64
#  1   Плотность, кг/м3                      1002 non-null   float64
#  2   модуль упругости, ГПа                 1002 non-null   float64
#  3   Количество отвердителя, м.%           1002 non-null   float64
#  4   Содержание эпоксидных групп,%_2       1002 non-null   float64
#  5   Температура вспышки, С_2              1002 non-null   float64
#  6   Поверхностная плотность, г/м2         1002 non-null   float64
#  7   Модуль упругости при растяжении, ГПа  1002 non-null   float64
#  8   Прочность при растяжении, МПа         1002 non-null   float64
#  9   Потребление смолы, г/м2               1002 non-null   float64
#  10  Угол нашивки, град                    1002 non-null   float64
#  11  Шаг нашивки                           1002 non-null   float64
#  12  Плотность нашивки                     1002 non-null   float64
# dtypes: float64(13)
# memory usage: 109.6 KB

# %%
df8 = df7.drop_duplicates(subset=['Модуль упругости при растяжении, ГПа'], keep='last')

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1002 entries, 18 to 1022
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Соотношение матрица-наполнитель       1002 non-null   float64
#  1   Плотность, кг/м3                      1002 non-null   float64
#  2   модуль упругости, ГПа                 1002 non-null   float64
#  3   Количество отвердителя, м.%           1002 non-null   float64
#  4   Содержание эпоксидных групп,%_2       1002 non-null   float64
#  5   Температура вспышки, С_2              1002 non-null   float64
#  6   Поверхностная плотность, г/м2         1002 non-null   float64
#  7   Модуль упругости при растяжении, ГПа  1002 non-null   float64
#  8   Прочность при растяжении, МПа         1002 non-null   float64
#  9   Потребление смолы, г/м2               1002 non-null   float64
#  10  Угол нашивки, град                    1002 non-null   float64
#  11  Шаг нашивки                           1002 non-null   float64
#  12  Плотность нашивки                     1002 non-null   float64
# dtypes: float64(13)
# memory usage: 109.6 KB

# %%
df9 = df8.drop_duplicates(subset=['Прочность при растяжении, МПа'], keep='last')

# %%
df9
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 18                           4.897959       1890.000000
# 22                           4.029126       1880.000000
# 23                           2.587348       1953.274926
# 24                           2.499918       1942.595777
# 25                           2.046471       2037.631811
# ...                               ...               ...
# 1018                         2.271346       1952.087902
# 1019                         3.444022       2050.089171
# 1020                         3.280604       1972.372865
# 1021                         3.705351       2066.799773
# 1022                         3.808020       1890.413468
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# 18               540.000000                   129.000000
# 22               622.000000                   111.860000
# 23              1136.596135                   137.627420
# 24               901.519947                   146.252208
# 25               707.570887                   101.617251
# ...                     ...                          ...
# 1018             912.855545                    86.992183
# 1019             444.732634                   145.981978
# 1020             416.836524                   110.533477
# 1021             741.475517                   141.397963
# 1022             417.316232                   129.183416
#
#       Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 18                          21.250000                300.000000
# 22                          22.267857                284.615385
# 23                          22.344534                234.716883
# 24                          23.081757                351.231874
# 25                          23.146393                312.307205
# ...                               ...                       ...
# 1018                        20.123249                324.774576
# 1019                        19.599769                254.215401
# 1020                        23.957502                248.423047
# 1021                        19.246945                275.779840
# 1022                        27.474763                300.952708
#
#       Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 18                       380.000000                             75.000000
# 22                       470.000000                             73.333333
# 23                       555.893453                             80.803222
# 24                       864.725484                             76.178075
# 25                       547.601219                             73.817067
# ...                             ...                                   ...
# 1018                     209.198700                             73.090961
# 1019                     350.660830                             72.920827
# 1020                     740.142791                             74.734344
# 1021                     641.468152                             74.042708
# 1022                     758.747882                             74.309704
#
#       Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 18                      1800.000000               120.000000
# 22                      2455.555556               220.000000
# 23                      2587.342983               246.613117
# 24                      3705.672523               226.222760
# 25                      2624.026407               178.198556
# ...                             ...                      ...
# 1018                    2387.292495               125.007669
# 1019                    2360.392784               117.730099
# 1020                    2662.906040               236.606764
# 1021                    2071.715856               197.126067
# 1022                    2856.328932               194.754342
#
#       Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 18                   0.0    10.000000          70.000000
# 22                  90.0     4.000000          60.000000
# 23                  90.0     4.000000          70.000000
# 24                  90.0     5.000000          47.000000
# 25                  90.0     5.000000          57.000000
# ...                  ...          ...                ...
# 1018                90.0     9.076380          47.019770
# 1019                90.0    10.565614          53.750790
# 1020                90.0     4.161154          67.629684
# 1021                90.0     6.313201          58.261074
# 1022                90.0     6.078902          77.434468
#
# [1002 rows x 13 columns]

# %%
df10 = df9.drop_duplicates(subset=['Потребление смолы, г/м2'], keep='last')

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1002 entries, 18 to 1022
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Соотношение матрица-наполнитель       1002 non-null   float64
#  1   Плотность, кг/м3                      1002 non-null   float64
#  2   модуль упругости, ГПа                 1002 non-null   float64
#  3   Количество отвердителя, м.%           1002 non-null   float64
#  4   Содержание эпоксидных групп,%_2       1002 non-null   float64
#  5   Температура вспышки, С_2              1002 non-null   float64
#  6   Поверхностная плотность, г/м2         1002 non-null   float64
#  7   Модуль упругости при растяжении, ГПа  1002 non-null   float64
#  8   Прочность при растяжении, МПа         1002 non-null   float64
#  9   Потребление смолы, г/м2               1002 non-null   float64
#  10  Угол нашивки, град                    1002 non-null   float64
#  11  Шаг нашивки                           1002 non-null   float64
#  12  Плотность нашивки                     1002 non-null   float64
# dtypes: float64(13)
# memory usage: 109.6 KB

# %%
df11 = df10.drop_duplicates(subset=['Угол нашивки, град'], keep='last')

# %%
df11
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 539                          2.455381       1955.866629
# 1022                         3.808020       1890.413468
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# 539              630.990666                   120.293014
# 1022             417.316232                   129.183416
#
#       Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 539                         17.251143                248.487787
# 1022                        27.474763                300.952708
#
#       Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 539                     1181.341388                             72.854580
# 1022                     758.747882                             74.309704
#
#       Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 539                     2193.814594               180.650170
# 1022                    2856.328932               194.754342
#
#       Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 539                  0.0     6.066474          56.798075
# 1022                90.0     6.078902          77.434468

# %%
df12 = df10.drop_duplicates(subset=['Шаг нашивки'], keep='last')

# %%
df12
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 23                           2.587348       1953.274926
# 27                           3.305535       1917.907506
# 31                           1.771436       1872.491560
# 35                           3.247617       1813.234600
# 39                           2.667697       2078.894676
# ...                               ...               ...
# 1018                         2.271346       1952.087902
# 1019                         3.444022       2050.089171
# 1020                         3.280604       1972.372865
# 1021                         3.705351       2066.799773
# 1022                         3.808020       1890.413468
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# 23              1136.596135                   137.627420
# 27               478.286247                   105.786930
# 31               801.033883                    79.794548
# 35               757.874479                    81.379871
# 39              1542.168458                   132.147403
# ...                     ...                          ...
# 1018             912.855545                    86.992183
# 1019             444.732634                   145.981978
# 1020             416.836524                   110.533477
# 1021             741.475517                   141.397963
# 1022             417.316232                   129.183416
#
#       Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 23                          22.344534                234.716883
# 27                          17.874100                328.154579
# 31                          22.296304                340.736898
# 35                          23.422465                279.080157
# 39                          22.650109                357.972896
# ...                               ...                       ...
# 1018                        20.123249                324.774576
# 1019                        19.599769                254.215401
# 1020                        23.957502                248.423047
# 1021                        19.246945                275.779840
# 1022                        27.474763                300.952708
#
#       Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 23                       555.893453                             80.803222
# 27                       526.692159                             72.345709
# 31                       864.929184                             70.947592
# 35                       575.062857                             69.341133
# 39                       787.299217                             76.471788
# ...                             ...                                   ...
# 1018                     209.198700                             73.090961
# 1019                     350.660830                             72.920827
# 1020                     740.142791                             74.734344
# 1021                     641.468152                             74.042708
# 1022                     758.747882                             74.309704
#
#       Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 23                      2587.342983               246.613117
# 27                      3059.032991               275.575880
# 31                      2796.785402               123.356264
# 35                      3188.136358               252.870569
# 39                      2559.643047               163.902778
# ...                             ...                      ...
# 1018                    2387.292495               125.007669
# 1019                    2360.392784               117.730099
# 1020                    2662.906040               236.606764
# 1021                    2071.715856               197.126067
# 1022                    2856.328932               194.754342
#
#       Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 23                  90.0     4.000000          70.000000
# 27                  90.0     5.000000          70.000000
# 31                  90.0     7.000000          70.000000
# 35                  90.0     9.000000          70.000000
# 39                  90.0    10.000000          70.000000
# ...                  ...          ...                ...
# 1018                90.0     9.076380          47.019770
# 1019                90.0    10.565614          53.750790
# 1020                90.0     4.161154          67.629684
# 1021                90.0     6.313201          58.261074
# 1022                90.0     6.078902          77.434468
#
# [988 rows x 13 columns]

# %%
df13 = df12.drop_duplicates(subset=['Плотность нашивки'], keep='last')

# %%
df13
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 39                           2.667697       2078.894676
# 40                           3.034399       1968.401388
# 41                           2.465205       1936.099137
# 42                           2.664389       1996.159145
# 43                           1.193530       1965.929227
# ...                               ...               ...
# 1018                         2.271346       1952.087902
# 1019                         3.444022       2050.089171
# 1020                         3.280604       1972.372865
# 1021                         3.705351       2066.799773
# 1022                         3.808020       1890.413468
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# 39              1542.168458                   132.147403
# 40               455.871019                    61.421297
# 41              1056.554985                    71.294058
# 42               525.057774                    77.506883
# 43               899.603701                   102.959069
# ...                     ...                          ...
# 1018             912.855545                    86.992183
# 1019             444.732634                   145.981978
# 1020             416.836524                   110.533477
# 1021             741.475517                   141.397963
# 1022             417.316232                   129.183416
#
#       Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 39                          22.650109                357.972896
# 40                          23.490723                316.414572
# 41                          24.523381                271.975678
# 42                          18.126107                223.408685
# 43                          19.566716                225.810223
# ...                               ...                       ...
# 1018                        20.123249                324.774576
# 1019                        19.599769                254.215401
# 1020                        23.957502                248.423047
# 1021                        19.246945                275.779840
# 1022                        27.474763                300.952708
#
#       Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 39                       787.299217                             76.471788
# 40                       637.376893                             75.090372
# 41                       129.077163                             66.420794
# 42                        28.658102                             69.489773
# 43                       871.088955                             73.454695
# ...                             ...                                   ...
# 1018                     209.198700                             73.090961
# 1019                     350.660830                             72.920827
# 1020                     740.142791                             74.734344
# 1021                     641.468152                             74.042708
# 1022                     758.747882                             74.309704
#
#       Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 39                      2559.643047               163.902778
# 40                      2848.490078               311.052398
# 41                      2868.586527               227.022557
# 42                      2220.587445               314.776669
# 43                      2335.541792                91.047646
# ...                             ...                      ...
# 1018                    2387.292495               125.007669
# 1019                    2360.392784               117.730099
# 1020                    2662.906040               236.606764
# 1021                    2071.715856               197.126067
# 1022                    2856.328932               194.754342
#
#       Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 39                  90.0    10.000000          70.000000
# 40                   0.0     7.856167          64.301964
# 41                   0.0     7.401543          19.250533
# 42                   0.0     6.675780          78.623299
# 43                   0.0     7.526398          38.176975
# ...                  ...          ...                ...
# 1018                90.0     9.076380          47.019770
# 1019                90.0    10.565614          53.750790
# 1020                90.0     4.161154          67.629684
# 1021                90.0     6.313201          58.261074
# 1022                90.0     6.078902          77.434468
#
# [984 rows x 13 columns]

# %%
plt.figure(figsize=(16, 6)) 
mask = np.triu(np.ones_like(df13.corr(), dtype=np.bool)) 
heatmap = sns.heatmap(df13.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG') 
heatmap.set_title('Карта корреляции параметров', fontdict={'fontsize':18}, pad=16)
#plt.savefig('Карта корреляции параметров.png', dpi=300, bbox_inches='tight')
# Out:
# C:\Users\vagid\AppData\Local\Temp/ipykernel_11704/806978635.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df13.corr(), dtype=np.bool))
# Text(0.5, 1.0, 'Карта корреляции параметров')

# %%
df13.to_csv('data/after_drop.csv')

# %%
corrmat = df13.corr()

f, ax = plt.subplots(figsize = (15, 8))
sns.heatmap(corrmat, ax = ax, cmap = 'rainbow', annot = True, linewidths = 1, linecolor = 'black');
# Корреляция признаков не изменилась

# %%
# %%time
sns.pairplot(df13, height = 2.5);
# Out:
# Wall time: 21.4 s

# %%
AA=df['Соотношение матрица-наполнитель']
BB=df['Плотность, кг/м3']

# %%
plt.scatter(AA, BB,  color='blue')
plt.plot(AA, BB, color='red', linewidth=2)
plt.show()

# %%
import pandas as pd

data = {'name': ['Somu', 'Kiku', 'Amol', 'Lini'],
	'physics': [68, 74, 77, 78],
	'chemistry': [84, 56, 73, 69],
	'algebra': [78, 88, 82, 87]}

	
#create dataframe
df_marks = pd.DataFrame(data)

#sort dataframe
sorted_df = df_marks.sort_values(by='algebra')
print(sorted_df)
# Out:
#    name  physics  chemistry  algebra
# 0  Somu       68         84       78
# 2  Amol       77         73       82
# 3  Lini       78         69       87
# 1  Kiku       74         56       88

# %%
df_marks
# Out:
#    name  physics  chemistry  algebra
# 0  Somu       68         84       78
# 1  Kiku       74         56       88
# 2  Amol       77         73       82
# 3  Lini       78         69       87

# %%
type(data)
# Out:
# dict

# %%
AA
# Out:
# 0       1.857143
# 1       1.857143
# 2       1.857143
# 3       1.857143
# 4       2.771331
#           ...
# 1018    2.271346
# 1019    3.444022
# 1020    3.280604
# 1021    3.705351
# 1022    3.808020
# Name: Соотношение матрица-наполнитель, Length: 1023, dtype: float64

# %%
AA.sort_values(ascending=True)
# Out:
# 673    0.389403
# 378    0.463342
# 785    0.547391
# 402    0.551508
# 820    0.596783
#          ...
# 895    5.314144
# 284    5.425139
# 505    5.452959
# 877    5.455566
# 237    5.591742
# Name: Соотношение матрица-наполнитель, Length: 1023, dtype: float64

# %%
BB.sort_values(ascending=True)
# Out:
# 918    1731.764635
# 873    1740.657496
# 326    1784.482245
# 204    1786.035636
# 593    1797.648234
#           ...
# 224    2182.751822
# 317    2184.493200
# 264    2192.297637
# 626    2192.738783
# 100    2207.773481
# Name: Плотность, кг/м3, Length: 1023, dtype: float64

# %%
#plt.scatter(AA, color='blue')
plt.plot(AA, color='red', linewidth=2)
plt.show()

# %%
plt.plot(BB, color='red', linewidth=2)
plt.show()

# %%
import pandas as pd
from  pylab import *
import pywt
#filename = 'Test_set/Bearing2_3/acc_00001.csv'
#df = pd.read_csv(filename, header=None)
signal = AA
v='bior4.4'
thres=[0.1,0.4,0.6]
for w in thres:
    def lowpassfilter(signal, thresh, wavelet=v):
        thresh = thresh*nanmax(signal)
        coeff = pywt.wavedec(signal, wavelet, level=8,mode="per" )
        coeff[1:] = (pywt.threshold(i, value=thresh, mode='soft' ) for i in coeff[1:])
        reconstructed_signal = pywt.waverec(coeff, wavelet, mode="per" )
        return reconstructed_signal
     
    fig, ax = subplots(figsize=(8,4))  
    ax.plot(signal, color="b", alpha=0.5, label='Оригинальный сигнал')
    rec = lowpassfilter(signal,w)
    ax.plot(rec, 'r', label='DWT преобразование сигнала', linewidth=2)
    ax.legend()
    ax.set_title('Удаление высокочастотного шума с помощью вейвлета :%s\n для порога детализации %s'%(v,w), fontsize=12)
    ax.set_ylabel('Амплитуда сигнала', fontsize=12)
    ax.set_xlabel('Время', fontsize=12)     
show()
# Out:
# A:\conda\lib\site-packages\pywt\_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# A:\conda\lib\site-packages\pywt\_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# A:\conda\lib\site-packages\pywt\_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(

# %%
from scipy import*
from pylab import*
import pandas as pd   
def kalman_filter( z, 
    F = eye(2), # матрица перехода состояний системы (transitionMatrix)
    Q = eye(2)*3e-3, # ковариация шума (processNoiseCov)
    H = eye(2), # матрица наблюдения (measurement)
    R = eye(2)*3e-1 # ковариация шума наблюдения (measurementNoiseCov)
            ):
    n = z.shape[0] # количество элементов
    #m = z.shape[1] # размерность пространства
    x = z[0,:].transpose() # начальное значение предсказания состояния системы
    P = Q # ковариационная матрица для экстраполированного вектора состояния
    r = [ x ] # результат
    for i in range(1,n):
        # экстраполяция:
        x = F.dot( x ) # экстраполяция (предсказание) состояния системы
        P = F.dot(P).dot( F.transpose() ) + Q # ковариационная матрица для экстраполированного вектора состояния
        # коррекция:
        y = z[i] - H.dot(x) # вектор ошибки, отклонение фактического наблюдения от ожидаемого (экстраполированного) наблюдения 
        S = H.dot(P).dot(H.transpose()) + R # ковариационная матрица для вектора отклонения (вектора ошибки)
        K = P.dot(H.transpose()).dot(linalg.inv(S)) # матрица коэффициентов усиления Калмана 
        x = x + K.dot(y) # коррекция оценки вектора состояния 
        P = ( eye(z.shape[1]) - K.dot(H) ).dot(P) # ковариационная матрица оценки вектора состояния системы
        r.append( x.transpose())
    return array(r)
#filename = 'Test_set/Bearing2_3/acc_00001.csv'
#df = pd.read_csv(filename, header=None)
signal = AA#df[4].values
N=  signal .shape[0] # длина последовательности
# 2 dimensions
y0 =linspace(0.0,2500.0,N) 
y1 =signal 
d  = array(list(zip(y0,y1)))
dn = d 
r =  kalman_filter(dn)
fig, ax = subplots(figsize=(8,4))
ax.plot( d[:,0], d[:,1],'b', label='Оригинальный сигнал' ) 
ax.plot( r[:,0], r[:,1],'r', label='kalman' )
ax.legend(loc='upper left')
ax.set_title('Удаление высокочастотного шума с помощью  фильтра Калмана \n (расчёт по алгоритму)', fontsize=12)                                            
ax.set_ylabel('Амплитуда сигнала', fontsize=12)
ax.set_xlabel('Время', fontsize=12)                   
show()

# %%
#<source lang="python">from scipy import *
import pandas as pd
from pylab import *
import pywt
import scaleogram as scg
def get_ave_values(xvalues, yvalues, n = 6):
    signal_length = len(xvalues)
    if signal_length % n == 0:
        padding_length = 0
    else:
        padding_length = n - signal_length//n % n
    xarr = array(xvalues)
    yarr = array(yvalues)
    xarr.resize(signal_length//n, n)
    yarr.resize(signal_length//n, n)
    xarr_reshaped = xarr.reshape((-1,n))
    yarr_reshaped = yarr.reshape((-1,n))
    x_ave = xarr_reshaped[:,0]
    y_ave = nanmean(yarr_reshaped, axis=1)
    return x_ave, y_ave
def plot_signal_plus_average(time, signal, average_over = 5):
    fig, ax = subplots(figsize=(8, 4))
    time_ave, signal_ave = get_ave_values(time, signal, average_over)    
    ax.plot(time_ave, signal_ave,"b", label = 'Скользящее среднее сигнала (n={})'.format(5))
    ax.set_xlim([time[0], time[-1]])
    ax.set_ylabel('Амплитуда сигнала', fontsize=12)
    ax.set_title('Фильтрация сигнала методом скользящего среднего SMA', fontsize=14)
    ax.set_xlabel('Время', fontsize=12)
    ax.legend()
    return signal_ave
#filename = 'Test_set/Bearing2_3/acc_00001.csv'
#df = pd.read_csv(filename, header=None)
df_nino = AA#df[4].values
N = df_nino.shape[0]
time = arange(0, N) 
signal = df_nino
signal_ave=plot_signal_plus_average(time, signal)

wavelet = 'cmor1-0.5' 
ax = ax = scg.cws(signal, scales=arange(1,40), wavelet=wavelet, figsize=(8, 4),cmap="jet", ylabel='Период ', xlabel="Время ", yscale="log",
title='CWT сигнала  %s \n(спектр мощности до фильтрации МСС )'%filename)
ax = ax = scg.cws(signal_ave, scales=arange(1,40), wavelet=wavelet, figsize=(8, 4), cmap="jet", ylabel='Период ', xlabel="Время ", yscale="log",
title='CWT сигнала  %s \n(спектр мощности после фильтрации МСС)'%filename)
show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11704/1085309124.py in <module>
#       3 from pylab import *
#       4 import pywt
# ----> 5 import scaleogram as scg
#       6 def get_ave_values(xvalues, yvalues, n = 6):
#       7     signal_length = len(xvalues)
#
# ModuleNotFoundError: No module named 'scaleogram'

# %%
X = df['Соотношение матрица-наполнитель'].values.reshape(-1,1)
y = df['Содержание эпоксидных групп,%_2'].values.reshape(-1,1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
#predicting the test set result
y_pred = regressor.predict(X_test)
#compare actual output values with predicted values
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df.head()
#prediction vs test set
plt.scatter(X_test, y_test,  color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
df
# Out:
#         Actual  Predicted
# 0    18.515894  22.098282
# 1    17.874100  22.274404
# 2    23.898728  22.242601
# 3    22.500389  22.367678
# 4    25.334082  22.274603
# ..         ...        ...
# 200  23.129981  22.184095
# 201  20.798849  22.256405
# 202  21.043501  22.203131
# 203  23.275623  22.168458
# 204  22.471660  22.243830
#
# [205 rows x 2 columns]
